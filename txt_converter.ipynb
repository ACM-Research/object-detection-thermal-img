# %%
#Clone repo for FLIR text file manipulation
# !git clone https://github.com/prat96/FLIR_to_Yolo
# %cd FLIR_to_Yolo
# !ls
# Out:
# Cloning into 'FLIR_to_Yolo'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 20 (delta 6), reused 14 (delta 4), pack-reused 0
# Receiving objects: 100% (20/20), 14.96 KiB | 382.00 KiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /Users/cesargamez/Downloads/FLIR_to_Yolo/FLIR_to_Yolo/FLIR_to_Yolo
# FLIR_2_yolo.py    LICENSE           README.md         fill_imagelist.py

# %%
# !python3 FLIR_2_yolo.py /Users/cesargamez/Desktop/FLIR_ADAS_v2/images_rgb_train /Users/cesargamez/Desktop/FLIR_txt/coco
# Out:
# sd9bsr962GdFBZ-frame-000221-arDqqfMYcrbEEqse
# sd9bsr962GdFBZ-frame-000236-CKrQ59pg7BzJDALS
# sd9bsr962GdFBZ-frame-000251-k8G4q7PbdPFf7Ymr
# sd9bsr962GdFBZ-frame-000266-gKf6k9v5tz6FM4ss
# sd9bsr962GdFBZ-frame-000281-WbvC2cEAjDaym8CG
# sd9bsr962GdFBZ-frame-000296-dRGbxkq3A7Lra86h
# sd9bsr962GdFBZ-frame-000311-556w9mWmCSbB5T8s
# sd9bsr962GdFBZ-frame-000780-hAbjjnmdC7WTThBn
# sd9bsr962GdFBZ-frame-000795-gN4LBaoAgpyEfBpk
# sd9bsr962GdFBZ-frame-000810-XupH9E3p2oGMGjyf
# sd9bsr962GdFBZ-frame-000825-9z3NdY9T2AbtkbZS
# sd9bsr962GdFBZ-frame-000840-PyHwr2ZvMLm9zjrm
# sd9bsr962GdFBZ-frame-000855-pdzjPoGCTjXjfSHd
# sd9bsr962GdFBZ-frame-000870-vJtKF4XNfpoguMoW
# sd9bsr962GdFBZ-frame-000885-BGcncn6byXQDFtnc
# sd9bsr962GdFBZ-frame-001054-TtSq4y8J2zKGkWfq
# sd9bsr962GdFBZ-frame-001069-37mTzoZTonMNotba
# sd9bsr962GdFBZ-frame-001084-rK5EjkuFTGG2SSAr
# sd9bsr962GdFBZ-frame-001099-32ERWX5mxfQjfPg4
# sd9bsr962GdFBZ-frame-001114-Rb3sqy6FbHuNKAcT
# sd9bsr962GdFBZ-frame-001129-6KTBj45ECyxj4M6t
# ...
